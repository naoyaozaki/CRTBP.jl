# %% [markdown]
# ---
# title: "Example Notebooks of Poincare Map" \
# author: "Naoya Ozaki" \
# date: "04 January 2024" \
# output: "poincare_map"
#
# ---

# %%
using LinearAlgebra

# Definition of Equation of Motion of Planar CRTBP
function eom_pcrtbp!(dx, x, μ, t)
    # Preparation
    r1 = x[1:2] + [μ, 0.0]
    r2 = x[1:2] - [1.0 - μ, 0.0]
    a_cori = [2.0x[4], -2.0x[3]]
    a_cf = [x[1], x[2]]
    # dx/dt
    dx[1:2] = x[3:4]
    dx[3:4] = -(1.0 - μ) * r1 / (norm(r1)^3) - μ * r2 / (norm(r2)^3) + a_cori + a_cf
end
# Out:
# eom_pcrtbp! (generic function with 1 method)

# %%
using DifferentialEquations

function condition(x, t, integrator) # Event when event_f(u,t) == 0
    r1_vec = x[1:2] + [μ,0]
    return r1_vec ⋅ x[3:4]
end

function affect!(integrator)
    nothing
end

function condition2(x, t, integrator) # Event when event_f(u,t) == 0
    r1 = x[1:2] + [μ, 0.0]
    r2 = x[1:2] - [1.0 - μ, 0.0]
    return norm(r1) > 1.0e-3 && norm(r2) > 1.0e-3
end

affect2!(integrator) = terminate!(integrator)

cb = ContinuousCallback(condition, nothing, affect!, save_positions=(true, false))
cb2 = ContinuousCallback(condition2, affect2!, save_positions=(false, false))
cbs = CallbackSet(cb, cb2)
# Out:
# CallbackSet{Tuple{ContinuousCallback{typeof(condition), Nothing, typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT), Float64, Int64, Rational{Int64}, Nothing, Int64}, ContinuousCallback{typeof(condition2), typeof(affect2!), typeof(affect2!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT), Float64, Int64, Rational{Int64}, Nothing, Int64}}, Tuple{}}((ContinuousCallback{typeof(condition), Nothing, typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT), Float64, Int64, Rational{Int64}, Nothing, Int64}(condition, nothing, affect!, SciMLBase.INITIALIZE_DEFAULT, SciMLBase.FINALIZE_DEFAULT, nothing, SciMLBase.LeftRootFind, 10, Bool[1, 0], 1, 2.220446049250313e-15, 0, 1//100), ContinuousCallback{typeof(condition2), typeof(affect2!), typeof(affect2!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT), Float64, Int64, Rational{Int64}, Nothing, Int64}(condition2, affect2!, affect2!, SciMLBase.INITIALIZE_DEFAULT, SciMLBase.FINALIZE_DEFAULT, nothing, SciMLBase.LeftRootFind, 10, Bool[0, 0], 1, 2.220446049250313e-15, 0, 1//100)), ())

# %%
jacobi_constant = 3.0
μ = 0.01215058426994 #5.667e-5 #0.01215058426994
qx0 = 1.1 + 5.0e-3*rand()
theta0 = 2.0 * pi * rand()
p0 = sqrt(-jacobi_constant + qx0^2 + 2.0 * (1.0 - μ) / abs(qx0 + μ) + 2.0 * μ / abs(qx0 - 1.0 + μ))
x0 = [qx0, 0.0, p0 * cos(theta0), p0 * sin(theta0)]
tspan = (0.0, 20.0*pi)
prob = ODEProblem(eom_pcrtbp!, x0, tspan, μ)
sol = solve(prob, Vern7(), callback=cbs, reltol=1e-10, abstol=1e-10, saveat=[-200.0 * pi, 0.0, 200.0 * pi])
sol_forplot = solve(prob, Vern7(), callback=cbs, reltol=1e-10, abstol=1e-10)
# Out:
# retcode: Success
# Interpolation: specialized 7th order lazy interpolation
# t: 618-element Vector{Float64}:
#   0.0
#   0.01758467518797807
#   0.031832231177076994
#   0.04906788312483344
#   0.06570484061160906
#   0.08328997412851095
#   0.10081288807717406
#   0.11862065133625815
#   0.13643173086989252
#   0.154326406699409
#   ⋮
#  61.80038713558107
#  61.92615247529235
#  62.053685904766446
#  62.18307736702076
#  62.31384332423215
#  62.44531482292174
#  62.576495736601515
#  62.70637378703129
#  62.83185307179586
# u: 618-element Vector{Vector{Float64}}:
#  [1.104718798609451, 0.0, -0.2949781198471445, 0.33209541835544737]
#  [1.0995415072337442, 0.005928496509139732, -0.29407705548491414, 0.3420333183120196]
#  [1.0953510319528663, 0.010854615870117846, -0.29430605610628663, 0.3493486250023869]
#  [1.0902678606239207, 0.016944671557844973, -0.29574958618320396, 0.3571169187982529]
#  [1.0853276681894382, 0.022939170235600114, -0.29831753511033127, 0.36326616515962834]
#  [1.0800494908041567, 0.029372152281884976, -0.30215941355564724, 0.3680578349760523]
#  [1.0747143284100251, 0.03584898794619605, -0.3069018576568551, 0.370832282043164]
#  [1.069201655514501, 0.04246124808562953, -0.3122878311894912, 0.371405531790585]
#  [1.063590411177138, 0.04906402908840521, -0.3177683934985304, 0.36962708254572235]
#  [1.057857720979635, 0.05564514229319968, -0.3228249916123897, 0.36554318320052354]
#  ⋮
#  [-2.6053099771244668, -5.064353230310022, -4.926868376197398, 2.3478584751989957]
#  [-3.206745572531525, -4.731650828262343, -4.625370680316223, 2.9372753691887903]
#  [-3.773274464364207, -4.32098854676813, -4.247279904678658, 3.4953995279302132]
#  [-4.294264245213203, -3.834715565926091, -3.794548657563036, 4.011805219685588]
#  [-4.757019685192243, -3.2791915007369274, -3.272955257541555, 4.473959485022854]
#  [-5.149682057178886, -2.66416256767419, -2.6915954988360444, 4.870043402239458]
#  [-5.4620482943680235, -2.0034783538150753, -2.0635970591597306, 5.189732115475932]
#  [-5.687602524387246, -1.3132005559462534, -1.4043502055535728, 5.426218134571454]
#  [-5.8224555113905225, -0.6221562335812663, -0.7416473658155576, 5.574915252350491]

# %%
x_all = hcat(sol.u...)'

r_1 = sqrt.((x_all[:, 1] .+ μ) .^ 2 + x_all[:, 2] .^ 2)
k_ene = 0.5 * ((x_all[:, 3] - x_all[:, 2]) .^ 2 + (x_all[:, 4] + x_all[:, 1] .+ μ) .^ 2)
a = -0.5 ./ (k_ene ./ (1.0 - μ) .- 1 ./ r_1)
theta = atan.(x_all[:, 2],x_all[:, 1] .+ μ)
# v_r = x_all[:, 3].*cos.(theta) + x_all[:,4].*sin.(theta)
# v_t = r_1 - x_all[:, 3] .* sin.(theta) + x_all[:, 4] .* cos.(theta)
# a = (r_1.*(1-μ))./(2*(1-μ) .- r_1.*(v_r.^2+v_t.^2))
# Out:
# 4-element Vector{Float64}:
#   0.0
#   0.11788973088332833
#  -0.12981579531270665
#   0.7946298961164814

# %%
using CairoMakie
Makie.inline!(true)

fig = Figure()
ax = Axis(fig[1, 1]; xlabel=L"x", ylabel=L"y")
scatter!(-μ, 0.0; markersize=20, color=:blue)
scatter!(1.0 - μ, 0.0; markersize=20, color=:gray)
lines!(sol_forplot[1, :], sol_forplot[2, :]; linewidth=1, color=:black)
scatter!(sol[1, 2:end-1], sol[2, 2:end-1]; markersize=20, color=:red)
ax.aspect = DataAspect()
fig

# %%
using CairoMakie

fig = Figure()
ax = Axis(fig[1, 1])
scatter!(theta[2:end-1] / pi, a[2:end-1], color=:black, markersize=2)
xlims!(-1, 1)
# ylims!(1.1, 1.8)
ylims!(0.4, 0.65)
fig

# %% [markdown]
# # 2. `EnsembleProblem`による並列計算の実行

# %%
using Distributed
using DifferentialEquations

addprocs(exeflags="--project=$(Base.active_project())")
@everywhere using DifferentialEquations
@everywhere using LinearAlgebra

@everywhere num_trj = 10000
@everywhere μ = 5.667e-5 #0.01215058426994
@everywhere qx0_all = LinRange(0.2, 2.5, num_trj)

# %%
@everywhere t_fin = 2.0 * pi * 500
tspan = (0.0, t_fin)
prob = ODEProblem(eom_pcrtbp!, x0, tspan, μ)

# Definition of Equation of Motion of Planar CRTBP
@everywhere function eom_pcrtbp!(dx, x, μ, t)
    # Preparation
    r1 = x[1:2] + [μ, 0.0]
    r2 = x[1:2] - [1.0 - μ, 0.0]
    a_cori = [2.0x[4], -2.0x[3]]
    a_cf = [x[1], x[2]]
    # dx/dt
    dx[1:2] = x[3:4]
    dx[3:4] = -(1.0 - μ) * r1 / (norm(r1)^3) - μ * r2 / (norm(r2)^3) + a_cori + a_cf
end

@everywhere function prob_func(prob, i, repeat)
    jacobi_constant = 3.0
    qx0 = qx0_all[i] #1.2rand() #1.1 + 5.0e-3 * rand()
    theta0 = 0.0 #2.0 * pi * rand()
    p0 = sqrt(-jacobi_constant + qx0^2 + 2.0 * (1.0 - μ) / abs(qx0 + μ) + 2.0 * μ / abs(qx0 - 1.0 + μ))
    x0 = [qx0, 0.0, p0 * cos(theta0), p0 * sin(theta0)]
    remake(prob, u0=x0)
end

@everywhere function condition(x, t, integrator) # Event when event_f(u,t) == 0
    r1_vec = x[1:2] + [μ,0.0]
    return r1_vec ⋅ x[3:4]
end

@everywhere function affect!(integrator)
    nothing
end

@everywhere function condition2(x, t, integrator) # Event when event_f(u,t) == 0
    r1 = x[1:2] + [μ, 0.0]
    r2 = x[1:2] - [1.0 - μ, 0.0]
    return norm(r1) > 1.0e-3 && norm(r2) > 1.0e-3
end

@everywhere affect2!(integrator) = terminate!(integrator)

cb = ContinuousCallback(condition, nothing, affect!, save_positions=(true, false))
cb2 = ContinuousCallback(condition2, affect2!, save_positions=(false, false))
cbs = CallbackSet(cb, cb2)

ensemble_prob = EnsembleProblem(prob, prob_func=prob_func)
sim_pos = solve(ensemble_prob, Vern7(), EnsembleDistributed(), trajectories=num_trj, callback=cbs, saveat=t_fin)
# Out:
#       From worker 5:	┌ Warning: dt(4.547473508864641e-13) <= dtmin(4.547473508864641e-13) at t=0.0004701656054319792. Aborting. There is either an error in your model specification or the true solution is unstable.
#       From worker 5:	└ @ SciMLBase ~/.julia/packages/SciMLBase/lGVlK/src/integrator_interface.jl:518
#       From worker 5:	┌ Warning: dt(4.547473508864641e-13) <= dtmin(4.547473508864641e-13) at t=0.00011892867703073289. Aborting. There is either an error in your model specification or the true solution is unstable.
#       From worker 5:	└ @ SciMLBase ~/.julia/packages/SciMLBase/lGVlK/src/integrator_interface.jl:518
# EnsembleSolution Solution of length 10000 with uType:
# ODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Vector{Float64}}}, ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Float64, ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float64}, Vector{Float64}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{Float64}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, Vern7, OrdinaryDiffEq.InterpolationData{ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float64}, Vector{Float64}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{Float64}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Vector{Float64}}, Vector{Float64}, Vector{Vector{Vector{Float64}}}, OrdinaryDiffEq.Vern7Cache{Vector{Float64}, Vector{Float64}, Vector{Float64}, OrdinaryDiffEq.Vern7Tableau{Float64, Float64}}}, DiffEqBase.DEStats, Nothing}

# %%
using CairoMakie

fig = Figure(; resolution=(1024, 1024))
ax = Axis(fig[1, 1])

for n = 1:num_trj
    x_all = hcat(sim_pos[n].u...)'

    r_1 = sqrt.((x_all[:, 1] .+ μ) .^ 2 + x_all[:, 2] .^ 2)
    k_ene = 0.5 * ((x_all[:, 3] - x_all[:, 2]) .^ 2 + (x_all[:, 4] + x_all[:, 1] .+ μ) .^ 2)
    a = -0.5 ./ (k_ene ./ (1.0 - μ) .- 1.0 ./ r_1)
    theta = atan.(x_all[:, 2],x_all[:, 1] .+ μ)

    scatter!(mod2pi.(theta[2:end-1]), a[2:end-1], color=:black, markersize=0.5)
end

xlims!(0.0, 2.0pi)
ylims!(0.5, 2.0)
# ylims!(0.2, 0.8)
fig

# %%
# Negative Time Propagation
@everywhere t_fin = -2.0 * pi * 500
tspan = (0.0, t_fin)
prob = ODEProblem(eom_pcrtbp!, x0, tspan, μ)

# Definition of Equation of Motion of Planar CRTBP
@everywhere function eom_pcrtbp!(dx, x, μ, t)
    # Preparation
    r1 = x[1:2] + [μ, 0.0]
    r2 = x[1:2] - [1.0 - μ, 0.0]
    a_cori = [2.0x[4], -2.0x[3]]
    a_cf = [x[1], x[2]]
    # dx/dt
    dx[1:2] = x[3:4]
    dx[3:4] = -(1.0 - μ) * r1 / (norm(r1)^3) - μ * r2 / (norm(r2)^3) + a_cori + a_cf
end

@everywhere function prob_func(prob, i, repeat)
    jacobi_constant = 3.0
    qx0 = qx0_all[i] #1.2rand() #1.1 + 5.0e-3 * rand()
    theta0 = 0.0 # 2.0 * pi * rand()
    p0 = sqrt(-jacobi_constant + qx0^2 + 2.0 * (1.0 - μ) / abs(qx0 + μ) + 2.0 * μ / abs(qx0 - 1.0 + μ))
    x0 = [qx0, 0.0, p0 * cos(theta0), p0 * sin(theta0)]
    remake(prob, u0=x0)
end

@everywhere function condition(x, t, integrator) # Event when event_f(u,t) == 0
    r1_vec = x[1:2] + [μ, 0.0]
    return r1_vec ⋅ x[3:4]
end

@everywhere function affect!(integrator)
    nothing
end

@everywhere function condition2(x, t, integrator) # Event when event_f(u,t) == 0
    r1 = x[1:2] + [μ, 0.0]
    r2 = x[1:2] - [1.0 - μ, 0.0]
    return norm(r1) > 1.0e-3 && norm(r2) > 1.0e-3
end

@everywhere affect2!(integrator) = terminate!(integrator)

cb = ContinuousCallback(condition, affect!, nothing, save_positions=(true, false))
cb2 = ContinuousCallback(condition2, affect2!, save_positions=(false, false))
cbs = CallbackSet(cb, cb2)

ensemble_prob = EnsembleProblem(prob, prob_func=prob_func)
sim_neg = solve(ensemble_prob, Vern7(), EnsembleDistributed(), trajectories=num_trj, callback=cbs, saveat=t_fin)
# Out:
#       From worker 5:	┌ Warning: dt(-3.202848431695087e-13) <= dtmin(4.547473508864641e-13) at t=-0.0003364005738787606. Aborting. There is either an error in your model specification or the true solution is unstable.
#       From worker 5:	└ @ SciMLBase ~/.julia/packages/SciMLBase/lGVlK/src/integrator_interface.jl:518
#       From worker 2:	┌ Warning: dt(-3.421463567752023e-13) <= dtmin(4.547473508864641e-13) at t=-4.204258618290976e-5. Aborting. There is either an error in your model specification or the true solution is unstable.
#       From worker 2:	└ @ SciMLBase ~/.julia/packages/SciMLBase/lGVlK/src/integrator_interface.jl:518
# EnsembleSolution Solution of length 10000 with uType:
# ODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Vector{Float64}}}, ODEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Float64, ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float64}, Vector{Float64}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{Float64}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}}, SciMLBase.StandardODEProblem}, Vern7, OrdinaryDiffEq.InterpolationData{ODEFunction{true, SciMLBase.AutoSpecialize, FunctionWrappersWrappers.FunctionWrappersWrapper{Tuple{FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{Float64}, Vector{Float64}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, Float64}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{Float64}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}, FunctionWrappers.FunctionWrapper{Nothing, Tuple{Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Vector{ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}, Float64, ForwardDiff.Dual{ForwardDiff.Tag{DiffEqBase.OrdinaryDiffEqTag, Float64}, Float64, 1}}}}, false}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Vector{Float64}}, Vector{Float64}, Vector{Vector{Vector{Float64}}}, OrdinaryDiffEq.Vern7Cache{Vector{Float64}, Vector{Float64}, Vector{Float64}, OrdinaryDiffEq.Vern7Tableau{Float64, Float64}}}, DiffEqBase.DEStats, Nothing}

# %%
for n = 1:num_trj
    x_all = hcat(sim_neg[n].u...)'

    r_1 = sqrt.((x_all[:, 1] .+ μ) .^ 2 + x_all[:, 2] .^ 2)
    k_ene = 0.5 * ((x_all[:, 3] - x_all[:, 2]) .^ 2 + (x_all[:, 4] + x_all[:, 1] .+ μ) .^ 2)
    a = -0.5 ./ (k_ene ./ (1.0 - μ) .- 1.0 ./ r_1)
    theta = atan.(x_all[:, 2],x_all[:, 1] .+ μ)

    scatter!(mod2pi.(theta[2:end-1]), a[2:end-1], color=:black, markersize=0.5)
end

xlims!(0.0, 2.0pi)
ylims!(0.5, 2.0)
# ylims!(0.2, 0.8)
# ylims!(0.4, 0.65)
ax.xlabel = "theta [rad]" 
ax.ylabel = "a [-]"
fig
